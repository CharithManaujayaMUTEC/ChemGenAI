# %% [markdown]
# <a href="https://colab.research.google.com/github/CharithManaujayaMUTEC/ChemGenAI/blob/main/Day1_Dataset_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit-pypi transformers datasets
# Out:
# ERROR: Could not find a version that satisfies the requirement rdkit-pypi (from versions: none)
# ERROR: No matching distribution found for rdkit-pypi
